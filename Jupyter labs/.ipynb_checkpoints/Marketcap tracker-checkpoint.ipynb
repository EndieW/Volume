# %% [markdown]
# # Market Cap Tracker

# %% [markdown]
# Using Crypto compare api

# %%
import requests,json,datetime,time,random, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from urllib.parse import urljoin, urlencode
import csv

# %% [markdown]
# # Path
# 1) collect volume data
#
# 2) process volume data
#
# 3) create DF with volume data
#
# 4) collect new data
#
# 5) process data[i]
#
# 6) add new data to previous DF
#
# 7) do till 5 sets of data

# %%
# Out:
# '14'

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2020-08-13 14:13:38.145179')

# %%
counter = 0 
def firstData(df):
    returndf = df.copy()
    name = 'VOLUME24HOURTO-%s' % (str(pd.Timestamp.now())[16:18])
    url = 'https://min-api.cryptocompare.com/data/top/volumes?tsym=BTC&limit=1000'
    output = requests.get(url)
    content = json.loads(output.content.decode('utf-8'))
    df = pd.DataFrame(content['Data'])
    df = df.set_index('SYMBOL')
    df[name] = df['VOLUME24HOURTO']
    returndf.join(df[name])
    return returndf

# %%
def secondData(df):
    df = df.copy()
    url = 'https://min-api.cryptocompare.com/data/top/volumes?tsym=BTC&limit=1000'
    output = requests.get(url)
    content = json.loads(output.content.decode('utf-8'))
    df2 = pd.DataFrame(content['Data'])
    df2 = df2.set_index('SYMBOL')
    df['VOLUME24HOURTO-2'] = df2['VOLUME24HOURTO']
    return df

# %%
# Out:
#               SUPPLY            FULLNAME         NAME      ID  VOLUME24HOURTO
# SYMBOL
# LIPS    0.000000e+00     LipChain (LIPS)     LipChain  928569    1.300729e+07
# ETH     1.121617e+08      Ethereum (ETH)     Ethereum    7605    3.725463e+04
# LINK    1.000000e+09    Chainlink (LINK)    Chainlink  309621    2.864523e+04
# SXP     2.997541e+08         Swipe (SXP)        Swipe  931777    7.566843e+03
# XTZ     8.109049e+08         Tezos (XTZ)        Tezos  166390    6.581793e+03
# ...              ...                 ...          ...     ...             ...
# LTHN    4.412502e+08      Lethean (LTHN)      Lethean  522090    1.730442e-03
# NYN     0.000000e+00         NYNJA (NYN)        NYNJA  924307    1.697220e-03
# FACE    9.385383e+08     Faceter  (FACE)     Faceter   892684    1.667770e-03
# DXO     1.948125e+06        Dextro (DXO)       Dextro  933832    1.578013e-03
# MINX    0.000000e+00  InnovaMinex (MINX)  InnovaMinex  926448    1.575197e-03
#
# [1001 rows x 5 columns]

# %%
b = secondData(a)

# %%
c = secondData(b)

# %%
a
# Out:
#               SUPPLY            FULLNAME          NAME      ID  VOLUME24HOURTO
# SYMBOL
# LIPS    0.000000e+00     LipChain (LIPS)      LipChain  928569    1.300729e+07
# ETH     1.121619e+08      Ethereum (ETH)      Ethereum    7605    3.774923e+04
# LINK    1.000000e+09    Chainlink (LINK)     Chainlink  309621    2.894644e+04
# SXP     2.997541e+08         Swipe (SXP)         Swipe  931777    7.632624e+03
# BCH     1.848866e+07  Bitcoin Cash (BCH)  Bitcoin Cash  202330    6.681883e+03
# ...              ...                 ...           ...     ...             ...
# NSD     2.261032e+07     Nasdacoin (NSD)     Nasdacoin  930124    1.962194e-03
# THX!    7.200000e+08       Thx! (THANKS)          Thx!  934363    1.872000e-03
# XSG     0.000000e+00       Snowgem (XSG)       Snowgem  847395    1.856887e-03
# LTHN    4.412502e+08      Lethean (LTHN)       Lethean  522090    1.730442e-03
# NYN     0.000000e+00         NYNJA (NYN)         NYNJA  924307    1.697220e-03
#
# [1001 rows x 5 columns]

# %% [markdown]
# quick question, not sure how to formulate it properly.
#
# I want a function to run an indefinite amount of times, but it needs to run every hour.
#
# I can do this with a
# ```
# while True
#     function()
#     time.sleep(3600)
# ```
# Function1() returns a pandas df
#
# Function2() takes in pandas df, and appends a new column based on an api,

# %%
a = firstData(df)

# %%
url = 'https://min-api.cryptocompare.com/data/top/volumes?tsym=BTC&limit=1000'
output = requests.get(url)
content = json.loads(output.content.decode('utf-8'))
df = pd.DataFrame(content['Data'])
df = df.set_index('SYMBOL')

# %%
df
# Out:
#               SUPPLY            FULLNAME         NAME      ID  VOLUME24HOURTO
# SYMBOL
# LIPS    0.000000e+00     LipChain (LIPS)     LipChain  928569    1.300729e+07
# ETH     1.121617e+08      Ethereum (ETH)     Ethereum    7605    3.725463e+04
# LINK    1.000000e+09    Chainlink (LINK)    Chainlink  309621    2.864523e+04
# SXP     2.997541e+08         Swipe (SXP)        Swipe  931777    7.566843e+03
# XTZ     8.109049e+08         Tezos (XTZ)        Tezos  166390    6.581793e+03
# ...              ...                 ...          ...     ...             ...
# LTHN    4.412502e+08      Lethean (LTHN)      Lethean  522090    1.730442e-03
# NYN     0.000000e+00         NYNJA (NYN)        NYNJA  924307    1.697220e-03
# FACE    9.385383e+08     Faceter  (FACE)     Faceter   892684    1.667770e-03
# DXO     1.948125e+06        Dextro (DXO)       Dextro  933832    1.578013e-03
# MINX    0.000000e+00  InnovaMinex (MINX)  InnovaMinex  926448    1.575197e-03
#
# [1001 rows x 5 columns]

# %%
output2 = requests.get(url)
content2 = json.loads(output2.content.decode('utf-8'))
df2 = pd.DataFrame(content2['Data'])
df2 = df2.set_index('SYMBOL')

# %%
output4 = requests.get(url)
content4 = json.loads(output4.content.decode('utf-8'))
df4 = pd.DataFrame(content2['Data'])
df4 = df4.set_index('SYMBOL')

# %%
df3 = df.join(df2['VOLUME24HOURTO'],rsuffix='_right')

# %%
df3.head(50)
# Out:
#               SUPPLY                      FULLNAME                    NAME  \
# SYMBOL
# LIPS    0.000000e+00               LipChain (LIPS)                LipChain
# ETH     1.121605e+08                Ethereum (ETH)                Ethereum
# LINK    1.000000e+09              Chainlink (LINK)               Chainlink
# SXP     2.997541e+08                   Swipe (SXP)                   Swipe
# XTZ     8.109049e+08                   Tezos (XTZ)                   Tezos
# BCH     1.848845e+07            Bitcoin Cash (BCH)            Bitcoin Cash
# XRP     9.999185e+10                     XRP (XRP)                     XRP
# BAND    1.000000e+08          Band Protocol (BAND)           Band Protocol
# COMP    1.000000e+07               Compound (COMP)                Compound
# LTC     6.567250e+07                Litecoin (LTC)                Litecoin
# ATOM    1.906884e+08                 Cosmos (ATOM)                  Cosmos
# EOS     1.020545e+09                     EOS (EOS)                     EOS
# SRM     1.610000e+08                   Serum (SRM)                   Serum
# ETC     1.202434e+08        Ethereum Classic (ETC)        Ethereum Classic
# WAVES   1.000000e+08                 Waves (WAVES)                   Waves
# AST     5.000000e+08                 AirSwap (AST)                 AirSwap
# ALGO    6.414234e+08               Algorand (ALGO)                Algorand
# IRIS    0.000000e+00           IRIS Network (IRIS)            IRIS Network
# ADA     2.592707e+10                 Cardano (ADA)                 Cardano
# OGN     1.000000e+09         Origin Protocol (OGN)         Origin Protocol
# BSV     1.848703e+07              Bitcoin SV (BSV)              Bitcoin SV
# ZEC     9.803794e+06                   ZCash (ZEC)                   ZCash
# KNC     2.104520e+08           Kyber Network (KNC)           Kyber Network
# MANA    2.195723e+09           Decentraland (MANA)            Decentraland
# BNB     1.555367e+08            Binance Coin (BNB)            Binance Coin
# VET     5.545473e+10                 VeChain (VET)                 VeChain
# JST     0.000000e+00                    JUST (JST)                    JUST
# ACHN    0.000000e+00                 Achain (ACHN)                  Achain
# LEND    1.300000e+09                   Aave (LEND)                    Aave
# TRX     6.675203e+10                    TRON (TRX)                    TRON
# NEO     1.000000e+08                     NEO (NEO)                     NEO
# ANKR    1.000000e+10           Ankr Network (ANKR)            Ankr Network
# CRO     1.000000e+11  Crypto.com Chain Token (CRO)  Crypto.com Chain Token
# OKB     3.000000e+08                    Okex (OKB)                    Okex
# MKR     1.005577e+06                   Maker (MKR)                   Maker
# ONT     6.373512e+08                Ontology (ONT)                Ontology
# SOLAN   0.000000e+00                Solana (SOLAN)                  Solana
# TRUE    1.000000e+08             True Chain (TRUE)              True Chain
# EM      2.100000e+09                   Eminer (EM)                  Eminer
# MATIC   1.000000e+10         Matic Network (MATIC)           Matic Network
# ZIL     9.946244e+09                 Zilliqa (ZIL)                 Zilliqa
# DNT     1.000000e+09              district0x (DNT)              district0x
# SNX     0.000000e+00               Synthetix (SNX)               Synthetix
# XLM     2.022342e+10                 Stellar (XLM)                 Stellar
# WRX     0.000000e+00                  WazirX (WRX)                  WazirX
# SEELE   1.000000e+09                 Seele (SEELE)                   Seele
# ZRX     1.000000e+09                      0x (ZRX)                      0x
# QTUM    1.000000e+08                   QTUM (QTUM)                    QTUM
# KAVA    0.000000e+00                   Kava (KAVA)                    Kava
# THETA   1.000000e+09                 Theta (THETA)                   Theta
#
#             ID  VOLUME24HOURTO  VOLUME24HOURTO_right
# SYMBOL
# LIPS    928569    1.300729e+07          1.300729e+07
# ETH       7605    3.430742e+04          3.479299e+04
# LINK    309621    2.704900e+04          2.739253e+04
# SXP     931777    7.062157e+03          7.175268e+03
# XTZ     166390    6.734346e+03          6.762097e+03
# BCH     202330    6.272322e+03          6.329707e+03
# XRP       5031    4.838241e+03          4.906895e+03
# BAND    932096    4.023603e+03          4.048438e+03
# COMP    935546    3.456364e+03          3.508044e+03
# LTC       3808    3.188133e+03          3.245038e+03
# ATOM    199107    3.157406e+03          3.167526e+03
# EOS     166503    3.053888e+03          3.080565e+03
# SRM     936118    3.031623e+03          3.047579e+03
# ETC       5324    2.869471e+03          2.878831e+03
# WAVES    20131    2.678366e+03          2.697964e+03
# AST     337162    2.659914e+03          2.660742e+03
# ALGO    930992    2.581326e+03          2.588775e+03
# IRIS    930935    2.330847e+03          2.341506e+03
# ADA     321992    2.272717e+03          2.283347e+03
# OGN     933180    2.172366e+03          2.178134e+03
# BSV     926591    2.172266e+03          2.185656e+03
# ZEC      24854    2.033767e+03          2.046432e+03
# KNC     310497    1.964700e+03          1.980971e+03
# MANA    199148    1.850079e+03          1.851978e+03
# BNB     204788    1.817574e+03          1.831895e+03
# VET     236131    1.674008e+03          1.689175e+03
# JST     934837    1.642768e+03          1.657450e+03
# ACHN    446372    1.628010e+03          1.628265e+03
# LEND    418778    1.624036e+03          1.638718e+03
# TRX     310829    1.611803e+03          1.614506e+03
# NEO      27368    1.475369e+03          1.485410e+03
# ANKR    929313    1.452693e+03          1.462223e+03
# CRO     929418    1.364583e+03          1.376351e+03
# OKB     925144    1.354172e+03          1.354295e+03
# MKR      41192    1.297660e+03          1.304398e+03
# ONT     808414    1.236744e+03          1.249262e+03
# SOLAN   934443    1.228443e+03          1.234244e+03
# TRUE    887527    1.102150e+03          1.102153e+03
# EM      931750    1.077073e+03          1.078874e+03
# MATIC   930246    1.023159e+03          1.037222e+03
# ZIL     716725    1.014320e+03          1.023031e+03
# DNT     177175    9.812559e+02          9.831471e+02
# SNX     816635    9.419901e+02          9.471861e+02
# XLM       4614    9.344305e+02          9.372020e+02
# WRX     933778    9.052219e+02          9.116723e+02
# SEELE   905749    9.001071e+02          9.001467e+02
# ZRX     186277    8.778631e+02          8.807393e+02
# QTUM    112392    8.643533e+02          8.732350e+02
# KAVA    932609    8.638300e+02          8.728141e+02
# THETA   714811    8.620319e+02          8.664973e+02

# %%
df.head(50)
# Out:
#               SUPPLY                      FULLNAME                    NAME  \
# SYMBOL
# LIPS    0.000000e+00               LipChain (LIPS)                LipChain
# ETH     1.121605e+08                Ethereum (ETH)                Ethereum
# LINK    1.000000e+09              Chainlink (LINK)               Chainlink
# SXP     2.997541e+08                   Swipe (SXP)                   Swipe
# XTZ     8.109049e+08                   Tezos (XTZ)                   Tezos
# BCH     1.848845e+07            Bitcoin Cash (BCH)            Bitcoin Cash
# XRP     9.999185e+10                     XRP (XRP)                     XRP
# BAND    1.000000e+08          Band Protocol (BAND)           Band Protocol
# COMP    1.000000e+07               Compound (COMP)                Compound
# LTC     6.567250e+07                Litecoin (LTC)                Litecoin
# ATOM    1.906884e+08                 Cosmos (ATOM)                  Cosmos
# EOS     1.020545e+09                     EOS (EOS)                     EOS
# SRM     1.610000e+08                   Serum (SRM)                   Serum
# ETC     1.202434e+08        Ethereum Classic (ETC)        Ethereum Classic
# WAVES   1.000000e+08                 Waves (WAVES)                   Waves
# AST     5.000000e+08                 AirSwap (AST)                 AirSwap
# ALGO    6.414234e+08               Algorand (ALGO)                Algorand
# IRIS    0.000000e+00           IRIS Network (IRIS)            IRIS Network
# ADA     2.592707e+10                 Cardano (ADA)                 Cardano
# OGN     1.000000e+09         Origin Protocol (OGN)         Origin Protocol
# BSV     1.848703e+07              Bitcoin SV (BSV)              Bitcoin SV
# ZEC     9.803794e+06                   ZCash (ZEC)                   ZCash
# KNC     2.104520e+08           Kyber Network (KNC)           Kyber Network
# MANA    2.195723e+09           Decentraland (MANA)            Decentraland
# BNB     1.555367e+08            Binance Coin (BNB)            Binance Coin
# VET     5.545473e+10                 VeChain (VET)                 VeChain
# JST     0.000000e+00                    JUST (JST)                    JUST
# ACHN    0.000000e+00                 Achain (ACHN)                  Achain
# LEND    1.300000e+09                   Aave (LEND)                    Aave
# TRX     6.675203e+10                    TRON (TRX)                    TRON
# NEO     1.000000e+08                     NEO (NEO)                     NEO
# ANKR    1.000000e+10           Ankr Network (ANKR)            Ankr Network
# CRO     1.000000e+11  Crypto.com Chain Token (CRO)  Crypto.com Chain Token
# OKB     3.000000e+08                    Okex (OKB)                    Okex
# MKR     1.005577e+06                   Maker (MKR)                   Maker
# ONT     6.373512e+08                Ontology (ONT)                Ontology
# SOLAN   0.000000e+00                Solana (SOLAN)                  Solana
# TRUE    1.000000e+08             True Chain (TRUE)              True Chain
# EM      2.100000e+09                   Eminer (EM)                  Eminer
# MATIC   1.000000e+10         Matic Network (MATIC)           Matic Network
# ZIL     9.946244e+09                 Zilliqa (ZIL)                 Zilliqa
# DNT     1.000000e+09              district0x (DNT)              district0x
# SNX     0.000000e+00               Synthetix (SNX)               Synthetix
# XLM     2.022342e+10                 Stellar (XLM)                 Stellar
# WRX     0.000000e+00                  WazirX (WRX)                  WazirX
# SEELE   1.000000e+09                 Seele (SEELE)                   Seele
# ZRX     1.000000e+09                      0x (ZRX)                      0x
# QTUM    1.000000e+08                   QTUM (QTUM)                    QTUM
# KAVA    0.000000e+00                   Kava (KAVA)                    Kava
# THETA   1.000000e+09                 Theta (THETA)                   Theta
#
#             ID  VOLUME24HOURTO
# SYMBOL
# LIPS    928569    1.300729e+07
# ETH       7605    3.430742e+04
# LINK    309621    2.704900e+04
# SXP     931777    7.062157e+03
# XTZ     166390    6.734346e+03
# BCH     202330    6.272322e+03
# XRP       5031    4.838241e+03
# BAND    932096    4.023603e+03
# COMP    935546    3.456364e+03
# LTC       3808    3.188133e+03
# ATOM    199107    3.157406e+03
# EOS     166503    3.053888e+03
# SRM     936118    3.031623e+03
# ETC       5324    2.869471e+03
# WAVES    20131    2.678366e+03
# AST     337162    2.659914e+03
# ALGO    930992    2.581326e+03
# IRIS    930935    2.330847e+03
# ADA     321992    2.272717e+03
# OGN     933180    2.172366e+03
# BSV     926591    2.172266e+03
# ZEC      24854    2.033767e+03
# KNC     310497    1.964700e+03
# MANA    199148    1.850079e+03
# BNB     204788    1.817574e+03
# VET     236131    1.674008e+03
# JST     934837    1.642768e+03
# ACHN    446372    1.628010e+03
# LEND    418778    1.624036e+03
# TRX     310829    1.611803e+03
# NEO      27368    1.475369e+03
# ANKR    929313    1.452693e+03
# CRO     929418    1.364583e+03
# OKB     925144    1.354172e+03
# MKR      41192    1.297660e+03
# ONT     808414    1.236744e+03
# SOLAN   934443    1.228443e+03
# TRUE    887527    1.102150e+03
# EM      931750    1.077073e+03
# MATIC   930246    1.023159e+03
# ZIL     716725    1.014320e+03
# DNT     177175    9.812559e+02
# SNX     816635    9.419901e+02
# XLM       4614    9.344305e+02
# WRX     933778    9.052219e+02
# SEELE   905749    9.001071e+02
# ZRX     186277    8.778631e+02
# QTUM    112392    8.643533e+02
# KAVA    932609    8.638300e+02
# THETA   714811    8.620319e+02

# %%
df2.head(50)
# Out:
#               SUPPLY                      FULLNAME                    NAME  \
# SYMBOL
# LIPS    0.000000e+00               LipChain (LIPS)                LipChain
# ETH     1.121606e+08                Ethereum (ETH)                Ethereum
# LINK    1.000000e+09              Chainlink (LINK)               Chainlink
# SXP     2.997541e+08                   Swipe (SXP)                   Swipe
# XTZ     8.109049e+08                   Tezos (XTZ)                   Tezos
# BCH     1.848845e+07            Bitcoin Cash (BCH)            Bitcoin Cash
# XRP     9.999185e+10                     XRP (XRP)                     XRP
# BAND    1.000000e+08          Band Protocol (BAND)           Band Protocol
# COMP    1.000000e+07               Compound (COMP)                Compound
# LTC     6.567252e+07                Litecoin (LTC)                Litecoin
# ATOM    1.906884e+08                 Cosmos (ATOM)                  Cosmos
# EOS     1.020545e+09                     EOS (EOS)                     EOS
# SRM     1.610000e+08                   Serum (SRM)                   Serum
# ETC     1.202434e+08        Ethereum Classic (ETC)        Ethereum Classic
# WAVES   1.000000e+08                 Waves (WAVES)                   Waves
# AST     5.000000e+08                 AirSwap (AST)                 AirSwap
# ALGO    6.414234e+08               Algorand (ALGO)                Algorand
# IRIS    0.000000e+00           IRIS Network (IRIS)            IRIS Network
# ADA     2.592707e+10                 Cardano (ADA)                 Cardano
# BSV     1.848703e+07              Bitcoin SV (BSV)              Bitcoin SV
# OGN     1.000000e+09         Origin Protocol (OGN)         Origin Protocol
# ZEC     9.803812e+06                   ZCash (ZEC)                   ZCash
# KNC     2.104520e+08           Kyber Network (KNC)           Kyber Network
# MANA    2.195723e+09           Decentraland (MANA)            Decentraland
# BNB     1.555367e+08            Binance Coin (BNB)            Binance Coin
# VET     5.545473e+10                 VeChain (VET)                 VeChain
# JST     0.000000e+00                    JUST (JST)                    JUST
# LEND    1.300000e+09                   Aave (LEND)                    Aave
# ACHN    0.000000e+00                 Achain (ACHN)                  Achain
# TRX     6.675203e+10                    TRON (TRX)                    TRON
# NEO     1.000000e+08                     NEO (NEO)                     NEO
# ANKR    1.000000e+10           Ankr Network (ANKR)            Ankr Network
# CRO     1.000000e+11  Crypto.com Chain Token (CRO)  Crypto.com Chain Token
# OKB     3.000000e+08                    Okex (OKB)                    Okex
# MKR     1.005577e+06                   Maker (MKR)                   Maker
# ONT     6.373512e+08                Ontology (ONT)                Ontology
# SOLAN   0.000000e+00                Solana (SOLAN)                  Solana
# TRUE    1.000000e+08             True Chain (TRUE)              True Chain
# EM      2.100000e+09                   Eminer (EM)                  Eminer
# MATIC   1.000000e+10         Matic Network (MATIC)           Matic Network
# ZIL     9.946244e+09                 Zilliqa (ZIL)                 Zilliqa
# DNT     1.000000e+09              district0x (DNT)              district0x
# SNX     0.000000e+00               Synthetix (SNX)               Synthetix
# XLM     2.022342e+10                 Stellar (XLM)                 Stellar
# WRX     0.000000e+00                  WazirX (WRX)                  WazirX
# SEELE   1.000000e+09                 Seele (SEELE)                   Seele
# ZRX     1.000000e+09                      0x (ZRX)                      0x
# QTUM    1.000000e+08                   QTUM (QTUM)                    QTUM
# KAVA    0.000000e+00                   Kava (KAVA)                    Kava
# THETA   1.000000e+09                 Theta (THETA)                   Theta
#
#             ID  VOLUME24HOURTO
# SYMBOL
# LIPS    928569    1.300729e+07
# ETH       7605    3.479299e+04
# LINK    309621    2.739253e+04
# SXP     931777    7.175268e+03
# XTZ     166390    6.762097e+03
# BCH     202330    6.329707e+03
# XRP       5031    4.906895e+03
# BAND    932096    4.048438e+03
# COMP    935546    3.508044e+03
# LTC       3808    3.245038e+03
# ATOM    199107    3.167526e+03
# EOS     166503    3.080565e+03
# SRM     936118    3.047579e+03
# ETC       5324    2.878831e+03
# WAVES    20131    2.697964e+03
# AST     337162    2.660742e+03
# ALGO    930992    2.588775e+03
# IRIS    930935    2.341506e+03
# ADA     321992    2.283347e+03
# BSV     926591    2.185656e+03
# OGN     933180    2.178134e+03
# ZEC      24854    2.046432e+03
# KNC     310497    1.980971e+03
# MANA    199148    1.851978e+03
# BNB     204788    1.831895e+03
# VET     236131    1.689175e+03
# JST     934837    1.657450e+03
# LEND    418778    1.638718e+03
# ACHN    446372    1.628265e+03
# TRX     310829    1.614506e+03
# NEO      27368    1.485410e+03
# ANKR    929313    1.462223e+03
# CRO     929418    1.376351e+03
# OKB     925144    1.354295e+03
# MKR      41192    1.304398e+03
# ONT     808414    1.249262e+03
# SOLAN   934443    1.234244e+03
# TRUE    887527    1.102153e+03
# EM      931750    1.078874e+03
# MATIC   930246    1.037222e+03
# ZIL     716725    1.023031e+03
# DNT     177175    9.831471e+02
# SNX     816635    9.471861e+02
# XLM       4614    9.372020e+02
# WRX     933778    9.116723e+02
# SEELE   905749    9.001467e+02
# ZRX     186277    8.807393e+02
# QTUM    112392    8.732350e+02
# KAVA    932609    8.728141e+02
# THETA   714811    8.664973e+02

# %%
df4.head(50)
# Out:
#               SUPPLY                      FULLNAME                    NAME  \
# SYMBOL
# LIPS    0.000000e+00               LipChain (LIPS)                LipChain
# ETH     1.121606e+08                Ethereum (ETH)                Ethereum
# LINK    1.000000e+09              Chainlink (LINK)               Chainlink
# SXP     2.997541e+08                   Swipe (SXP)                   Swipe
# XTZ     8.109049e+08                   Tezos (XTZ)                   Tezos
# BCH     1.848845e+07            Bitcoin Cash (BCH)            Bitcoin Cash
# XRP     9.999185e+10                     XRP (XRP)                     XRP
# BAND    1.000000e+08          Band Protocol (BAND)           Band Protocol
# COMP    1.000000e+07               Compound (COMP)                Compound
# LTC     6.567252e+07                Litecoin (LTC)                Litecoin
# ATOM    1.906884e+08                 Cosmos (ATOM)                  Cosmos
# EOS     1.020545e+09                     EOS (EOS)                     EOS
# SRM     1.610000e+08                   Serum (SRM)                   Serum
# ETC     1.202434e+08        Ethereum Classic (ETC)        Ethereum Classic
# WAVES   1.000000e+08                 Waves (WAVES)                   Waves
# AST     5.000000e+08                 AirSwap (AST)                 AirSwap
# ALGO    6.414234e+08               Algorand (ALGO)                Algorand
# IRIS    0.000000e+00           IRIS Network (IRIS)            IRIS Network
# ADA     2.592707e+10                 Cardano (ADA)                 Cardano
# BSV     1.848703e+07              Bitcoin SV (BSV)              Bitcoin SV
# OGN     1.000000e+09         Origin Protocol (OGN)         Origin Protocol
# ZEC     9.803812e+06                   ZCash (ZEC)                   ZCash
# KNC     2.104520e+08           Kyber Network (KNC)           Kyber Network
# MANA    2.195723e+09           Decentraland (MANA)            Decentraland
# BNB     1.555367e+08            Binance Coin (BNB)            Binance Coin
# VET     5.545473e+10                 VeChain (VET)                 VeChain
# JST     0.000000e+00                    JUST (JST)                    JUST
# LEND    1.300000e+09                   Aave (LEND)                    Aave
# ACHN    0.000000e+00                 Achain (ACHN)                  Achain
# TRX     6.675203e+10                    TRON (TRX)                    TRON
# NEO     1.000000e+08                     NEO (NEO)                     NEO
# ANKR    1.000000e+10           Ankr Network (ANKR)            Ankr Network
# CRO     1.000000e+11  Crypto.com Chain Token (CRO)  Crypto.com Chain Token
# OKB     3.000000e+08                    Okex (OKB)                    Okex
# MKR     1.005577e+06                   Maker (MKR)                   Maker
# ONT     6.373512e+08                Ontology (ONT)                Ontology
# SOLAN   0.000000e+00                Solana (SOLAN)                  Solana
# TRUE    1.000000e+08             True Chain (TRUE)              True Chain
# EM      2.100000e+09                   Eminer (EM)                  Eminer
# MATIC   1.000000e+10         Matic Network (MATIC)           Matic Network
# ZIL     9.946244e+09                 Zilliqa (ZIL)                 Zilliqa
# DNT     1.000000e+09              district0x (DNT)              district0x
# SNX     0.000000e+00               Synthetix (SNX)               Synthetix
# XLM     2.022342e+10                 Stellar (XLM)                 Stellar
# WRX     0.000000e+00                  WazirX (WRX)                  WazirX
# SEELE   1.000000e+09                 Seele (SEELE)                   Seele
# ZRX     1.000000e+09                      0x (ZRX)                      0x
# QTUM    1.000000e+08                   QTUM (QTUM)                    QTUM
# KAVA    0.000000e+00                   Kava (KAVA)                    Kava
# THETA   1.000000e+09                 Theta (THETA)                   Theta
#
#             ID  VOLUME24HOURTO
# SYMBOL
# LIPS    928569    1.300729e+07
# ETH       7605    3.479299e+04
# LINK    309621    2.739253e+04
# SXP     931777    7.175268e+03
# XTZ     166390    6.762097e+03
# BCH     202330    6.329707e+03
# XRP       5031    4.906895e+03
# BAND    932096    4.048438e+03
# COMP    935546    3.508044e+03
# LTC       3808    3.245038e+03
# ATOM    199107    3.167526e+03
# EOS     166503    3.080565e+03
# SRM     936118    3.047579e+03
# ETC       5324    2.878831e+03
# WAVES    20131    2.697964e+03
# AST     337162    2.660742e+03
# ALGO    930992    2.588775e+03
# IRIS    930935    2.341506e+03
# ADA     321992    2.283347e+03
# BSV     926591    2.185656e+03
# OGN     933180    2.178134e+03
# ZEC      24854    2.046432e+03
# KNC     310497    1.980971e+03
# MANA    199148    1.851978e+03
# BNB     204788    1.831895e+03
# VET     236131    1.689175e+03
# JST     934837    1.657450e+03
# LEND    418778    1.638718e+03
# ACHN    446372    1.628265e+03
# TRX     310829    1.614506e+03
# NEO      27368    1.485410e+03
# ANKR    929313    1.462223e+03
# CRO     929418    1.376351e+03
# OKB     925144    1.354295e+03
# MKR      41192    1.304398e+03
# ONT     808414    1.249262e+03
# SOLAN   934443    1.234244e+03
# TRUE    887527    1.102153e+03
# EM      931750    1.078874e+03
# MATIC   930246    1.037222e+03
# ZIL     716725    1.023031e+03
# DNT     177175    9.831471e+02
# SNX     816635    9.471861e+02
# XLM       4614    9.372020e+02
# WRX     933778    9.116723e+02
# SEELE   905749    9.001467e+02
# ZRX     186277    8.807393e+02
# QTUM    112392    8.732350e+02
# KAVA    932609    8.728141e+02
# THETA   714811    8.664973e+02
